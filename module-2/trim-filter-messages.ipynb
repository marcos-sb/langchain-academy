# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to a project, `langchain-academy`.

# %%
_set_env("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model="qwen/qwen3-4b-2507",
    base_url="http://localhost:1234/v1",
    api_key="nothing",
    temperature=0.7,
    max_tokens=512)
llm.invoke(messages)
llm.get_num_tokens_from_messages()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 9
#       2 llm = ChatOpenAI(
#       3     model="qwen/qwen3-4b-2507",
#       4     base_url="http://localhost:1234/v1",
#       5     api_key="nothing",
#       6     temperature=0.7,
#       7     max_tokens=512)
#       8 llm.invoke(messages)
# ----> 9 llm.get_num_tokens_from_messages()
#
# TypeError: BaseChatOpenAI.get_num_tokens_from_messages() missing 1 required positional argument: 'messages'

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:207, in HTTPConnection._new_conn(self)
#     206 except SocketTimeout as e:
# --> 207     raise ConnectTimeoutError(
#     208         self,
#     209         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     210     ) from e
#     212 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x10c3aa0d0>, 'Connection to mermaid.ink timed out. (connect timeout=10)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='mermaid.ink', port=443): Max retries exceeded with url: ...?type=png&bgColor=!white (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10c3aa0d0>, 'Connection to mermaid.ink timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:448, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, base_url)
#     447 try:
# --> 448     response = requests.get(image_url, timeout=10)
#     449     if response.status_code == requests.codes.ok:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/adapters.py:665, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     if not isinstance(e.reason, NewConnectionError):
# --> 665         raise ConnectTimeout(e, request=request)
#     667 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='mermaid.ink', port=443): Max retries exceeded with url: ...?type=png&bgColor=!white (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10c3aa0d0>, 'Connection to mermaid.ink timed out. (connect timeout=10)'))
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 17
#      14 graph = builder.compile()
#      16 # View
# ---> 17 display(Image(graph.get_graph().draw_mermaid_png()))
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph.py:694, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url)
#     684 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     685     draw_mermaid_png,
#     686 )
#     688 mermaid_syntax = self.draw_mermaid(
#     689     curve_style=curve_style,
#     690     node_colors=node_colors,
#     691     wrap_label_n_words=wrap_label_n_words,
#     692     frontmatter_config=frontmatter_config,
#     693 )
# --> 694 return draw_mermaid_png(
#     695     mermaid_syntax=mermaid_syntax,
#     696     output_file_path=output_file_path,
#     697     draw_method=draw_method,
#     698     background_color=background_color,
#     699     padding=padding,
#     700     max_retries=max_retries,
#     701     retry_delay=retry_delay,
#     702     base_url=base_url,
#     703 )
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:310, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url)
#     304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
# --> 310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#     313         background_color=background_color,
#     314         max_retries=max_retries,
#     315         retry_delay=retry_delay,
#     316         base_url=base_url,
#     317     )
#     318 else:
#     319     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:480, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, base_url)
#     475         else:
#     476             msg = (
#     477                 f"Failed to reach {base_url} API while trying to render "
#     478                 f"your graph after {max_retries} retries. "
#     479             ) + error_msg_suffix
# --> 480             raise ValueError(msg) from e
#     482 # This should not be reached, but just in case
#     483 msg = (
#     484     f"Failed to reach {base_url} API while trying to render "
#     485     f"your graph after {max_retries} retries. "
#     486 ) + error_msg_suffix
#
# ValueError: Failed to reach https://mermaid.ink API while trying to render your graph after 1 retries. To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great starting point! Whales are fascinating, but there's a whole world of ocean mammals beyond them. Here are some key groups and species you might want to explore:
#
# ### 1. **Sperm Whales** (already known, but worth deepening)
# - The largest deep-diving mammals.
# - Known for their complex songs and hunting giant squid.
# - One of the few animals that can dive over 2,000 meters.
#
# ### 2. **Porpoises**
# - Smaller, faster, and more playful than whales.
# - Examples: **False killer whale**, **Indo-Pacific finless porpoise**, **Spotted porpoise**.
# - Often found in coastal waters and known for their agility and social behavior.
#
# ### 3. **Dolphins**
# - Highly intelligent and social, with complex communication and cooperation.
# - Species to learn about:
#   - **Bottlenose dolphin** (most studied)
#   - **Common dolphin**
#   - **Spinner dolphin** (known for their acrobatic spins)
#   - **Orca (killer whale)** — *not actually a killer, but a top predator and one of the most intelligent mammals.*
#
# 💡 Fun fact: Orca pods are known to have distinct cultural behaviors — like different hunting techniques or song traditions — passed down through generations.
#
# ### 4. **Seals**
# - Not fully aquatic — they spend time on land or ice.
# - Species:
#   - **Northern elephant seal** (largest seal, with massive males)
#   - **Harbor seal**
#   - **Leopard seal** (known for aggressive feeding habits)
# - Often found in polar and temperate waters.
#
# ### 5. **Sea Lions**
# - More terrestrial than seals, often seen barking on rocks.
# - Examples:
#   - **North Pacific (California) sea lion**
#   - **Southern sea lion**
# - Known for their vocalizations and social behaviors.
#
# ### 6. **Pinnipeds vs. Cetaceans**
# - **Pinnipeds** (seals, sea lions, fur seals): adapted to both land and sea.
# - **Cetaceans** (whales, dolphins): fully aquatic, with a more streamlined body.
#
# ### 7. **Rare or Mysterious Species**
# - **Pygmy mink** (a small, elusive marine mammal — not real, probably a mix-up!)
# - **False killer whale** (a type of orca, often mistaken for regular or

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:207, in HTTPConnection._new_conn(self)
#     206 except SocketTimeout as e:
# --> 207     raise ConnectTimeoutError(
#     208         self,
#     209         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     210     ) from e
#     212 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x10c4473d0>, 'Connection to mermaid.ink timed out. (connect timeout=10)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='mermaid.ink', port=443): Max retries exceeded with url: ...?type=png&bgColor=!white (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10c4473d0>, 'Connection to mermaid.ink timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:448, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, base_url)
#     447 try:
# --> 448     response = requests.get(image_url, timeout=10)
#     449     if response.status_code == requests.codes.ok:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/adapters.py:665, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     if not isinstance(e.reason, NewConnectionError):
# --> 665         raise ConnectTimeout(e, request=request)
#     667 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='mermaid.ink', port=443): Max retries exceeded with url: ...?type=png&bgColor=!white (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10c4473d0>, 'Connection to mermaid.ink timed out. (connect timeout=10)'))
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 22
#      19 graph = builder.compile()
#      21 # View
# ---> 22 display(Image(graph.get_graph().draw_mermaid_png()))
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph.py:694, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url)
#     684 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     685     draw_mermaid_png,
#     686 )
#     688 mermaid_syntax = self.draw_mermaid(
#     689     curve_style=curve_style,
#     690     node_colors=node_colors,
#     691     wrap_label_n_words=wrap_label_n_words,
#     692     frontmatter_config=frontmatter_config,
#     693 )
# --> 694 return draw_mermaid_png(
#     695     mermaid_syntax=mermaid_syntax,
#     696     output_file_path=output_file_path,
#     697     draw_method=draw_method,
#     698     background_color=background_color,
#     699     padding=padding,
#     700     max_retries=max_retries,
#     701     retry_delay=retry_delay,
#     702     base_url=base_url,
#     703 )
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:310, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url)
#     304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
# --> 310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#     313         background_color=background_color,
#     314         max_retries=max_retries,
#     315         retry_delay=retry_delay,
#     316         base_url=base_url,
#     317     )
#     318 else:
#     319     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:480, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, base_url)
#     475         else:
#     476             msg = (
#     477                 f"Failed to reach {base_url} API while trying to render "
#     478                 f"your graph after {max_retries} retries. "
#     479             ) + error_msg_suffix
# --> 480             raise ValueError(msg) from e
#     482 # This should not be reached, but just in case
#     483 msg = (
#     484     f"Failed to reach {base_url} API while trying to render "
#     485     f"your graph after {max_retries} retries. "
#     486 ) + error_msg_suffix
#
# ValueError: Failed to reach https://mermaid.ink API while trying to render your graph after 1 retries. To resolve this issue:
# 1. Check your internet connection and try again
# 2. Try with higher retry settings: `draw_mermaid_png(..., max_retries=5, retry_delay=2.0)`
# 3. Use the Pyppeteer rendering method which will render your graph locally in a browser: `draw_mermaid_png(..., draw_method=MermaidDrawMethod.PYPPETEER)`

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great starting point! Whales are fascinating, but the ocean is home to many other remarkable mammals—some of which are less well-known but just as incredible. Here’s a list of ocean mammals you might want to learn more about, grouped by type and interest:
#
# ---
#
# ### 🐬 1. **Sperm Whales** (You may know about them, but deep dive!)
# - **Fun Fact**: The largest brain of any animal (up to 12–15 lbs) — and they're known for deep dives to 2,000+ meters.
# - They hunt giant squid — one of the few animals known to hunt squid.
# - Unique among whales for their deep, prolonged dives and complex vocalizations.
#
# ---
#
# ### 🐬 2. **Porpoises** (Small but fierce!)
# - **Types**: Common, harbor, and spotted porpoises.
# - They're often confused with dolphins, but they're more solitary and have a more streamlined body.
# - Known for their quick, darting movements and loud, clicking sounds (used for echolocation).
#
# ---
#
# ### 🐬 3. **Dolphins** (Not just playful!)
# - **Types**: Common, spinner, bottlenose, and orca (killer whales).
# - **Orca (Orcinus orca)**: Not a "killer" in the sense of being murderous — they're intelligent, social, and even have distinct cultural "pod" behaviors.
# - Dolphins use tools, show complex social structures, and have advanced communication.
#
# ---
#
# ### 🐬 4. **Seals and Sea Lions** (Not fully aquatic — but ocean mammals!)
# - **Seals**: Harp, ringed, and elephant seals (some are on land most of the time).
# - **Sea lions**: More agile, spend time on rocks and can run on land — often seen barking and leaping.
# - They’re great for understanding marine mammals that rely on land for breeding.
#
# ---
#
# ### 🐬 5. **Pinnipeds (the group)** — seals, sea lions, and walruses
# - **Walruses** (e.g., Atlantic and Pacific walruses): Large, social, and known for their tusks (used for digging and defense).
# - They surface to breathe and often rest on ice or rocky shores.
#
# ---
#
# ### 🐬 6. **Manatees** (Not whales — but *very* oceanic!)
# - Gentle giants of the warm

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 13
#      10 graph = builder.compile()
#      12 # View
# ---> 13 display(Image(graph.get_graph().draw_mermaid_png()))
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph.py:694, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url)
#     684 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     685     draw_mermaid_png,
#     686 )
#     688 mermaid_syntax = self.draw_mermaid(
#     689     curve_style=curve_style,
#     690     node_colors=node_colors,
#     691     wrap_label_n_words=wrap_label_n_words,
#     692     frontmatter_config=frontmatter_config,
#     693 )
# --> 694 return draw_mermaid_png(
#     695     mermaid_syntax=mermaid_syntax,
#     696     output_file_path=output_file_path,
#     697     draw_method=draw_method,
#     698     background_color=background_color,
#     699     padding=padding,
#     700     max_retries=max_retries,
#     701     retry_delay=retry_delay,
#     702     base_url=base_url,
#     703 )
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:310, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url)
#     304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
# --> 310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#     313         background_color=background_color,
#     314         max_retries=max_retries,
#     315         retry_delay=retry_delay,
#     316         base_url=base_url,
#     317     )
#     318 else:
#     319     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:448, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, base_url)
#     446 for attempt in range(max_retries + 1):
#     447     try:
# --> 448         response = requests.get(image_url, timeout=10)
#     449         if response.status_code == requests.codes.ok:
#     450             img_bytes = response.content
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     751 try:
#     752     sock: socket.socket | ssl.SSLSocket
# --> 753     self.sock = sock = self._new_conn()
#     754     server_hostname: str = self.host
#     755     tls_in_tls = False
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great starting point! Whales are fascinating, but the ocean is home to many other remarkable mammals—some of which are less well-known but just as incredible. Here’s a list of ocean mammals you might want to learn more about, grouped by type and interest:
#
# ---
#
# ### 🐬 1. **Sperm Whales** (You may know about them, but deep dive!)
# - **Fun Fact**: The largest brain of any animal (up to 12–15 lbs) — and they're known for deep dives to 2,000+ meters.
# - They hunt giant squid — one of the few animals known to hunt squid.
# - Unique among whales for their deep, prolonged dives and complex vocalizations.
#
# ---
#
# ### 🐬 2. **Porpoises** (Small but fierce!)
# - **Types**: Common, harbor, and spotted porpoises.
# - They're often confused with dolphins, but they're more solitary and have a more streamlined body.
# - Known for their quick, darting movements and loud, clicking sounds (used for echolocation).
#
# ---
#
# ### 🐬 3. **Dolphins** (Not just playful!)
# - **Types**: Common, spinner, bottlenose, and orca (killer whales).
# - **Orca (Orcinus orca)**: Not a "killer" in the sense of being murderous — they're intelligent, social, and even have distinct cultural "pod" behaviors.
# - Dolphins use tools, show complex social structures, and have advanced communication.
#
# ---
#
# ### 🐬 4. **Seals and Sea Lions** (Not fully aquatic — but ocean mammals!)
# - **Seals**: Harp, ringed, and elephant seals (some are on land most of the time).
# - **Sea lions**: More agile, spend time on rocks and can run on land — often seen barking and leaping.
# - They’re great for understanding marine mammals that rely on land for breeding.
#
# ---
#
# ### 🐬 5. **Pinnipeds (the group)** — seals, sea lions, and walruses
# - **Walruses** (e.g., Atlantic and Pacific walruses): Large, social, and known for their tusks (used for digging and defense).
# - They surface to breathe and often rest on ice or rocky shores.
#
# ---
#
# ### 🐬 6. **Manatees** (Not whales — but *very* oceanic!)
# - Gentle giants of the warm
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great starting point! Whales are fascinating, but the ocean is home to many other remarkable mammals—some of which are less well-known but just as incredible. Here’s a list of ocean mammals you might want to learn more about, grouped by type and interest:
#
# ---
#
# ### 🐬 1. **Sperm Whales** (You may know about them, but deep dive!)
# - **Fun Fact**: The largest brain of any animal (up to 12–15 lbs) — and they're known for deep dives to 2,000+ meters.
# - They hunt giant squid — one of the few animals known to hunt squid.
# - Unique among whales for their deep, prolonged dives and complex vocalizations.
#
# ---
#
# ### 🐬 2. **Porpoises** (Small but fierce!)
# - **Types**: Common, harbor, and spotted porpoises.
# - They're often confused with dolphins, but they're more solitary and have a more streamlined body.
# - Known for their quick, darting movements and loud, clicking sounds (used for echolocation).
#
# ---
#
# ### 🐬 3. **Dolphins** (Not just playful!)
# - **Types**: Common, spinner, bottlenose, and orca (killer whales).
# - **Orca (Orcinus orca)**: Not a "killer" in the sense of being murderous — they're intelligent, social, and even have distinct cultural "pod" behaviors.
# - Dolphins use tools, show complex social structures, and have advanced communication.
#
# ---
#
# ### 🐬 4. **Seals and Sea Lions** (Not fully aquatic — but ocean mammals!)
# - **Seals**: Harp, ringed, and elephant seals (some are on land most of the time).
# - **Sea lions**: More agile, spend time on rocks and can run on land — often seen barking and leaping.
# - They’re great for understanding marine mammals that rely on land for breeding.
#
# ---
#
# ### 🐬 5. **Pinnipeds (the group)** — seals, sea lions, and walruses
# - **Walruses** (e.g., Atlantic and Pacific walruses): Large, social, and known for their tusks (used for digging and defense).
# - They surface to breathe and often rest on ice or rocky shores.
#
# ---
#
# ### 🐬 6. **Manatees** (Not whales — but *very* oceanic!)
# - Gentle giants of the warm
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Absolutely! Narwhals are one of the most fascinating and mysterious marine mammals — here’s everything you need to know about them:
#
# ### What is a Narwhal?
# The **narwhal** (*Monodon monoceros*) is a unique, Arctic-fin whale species known for its long, spiraled tusk — a feature that has fascinated scientists, sailors, and the public for centuries.
#
# Despite common myths, **the tusk is not a separate gendered or sexual organ** — it's actually a modified tooth, and in most narwhals, it's a single, elongated tusk (though some have two tusks, one from each side of the jaw).
#
# ---
#
# ### Key Facts About Narwhals
#
# #### 🐋 Habitat
# - Narwhals live exclusively in the **Arctic regions**.
# - They are found in the **North Atlantic and North Pacific Oceans**, primarily around the waters of Canada, Greenland, and Russia.
# - They inhabit **seasonal and deep waters**, often traveling under ice or near sea ice.
#
# #### 🐾 Physical Features
# - **Size**: About 5 to 6 meters (16 to 20 feet) long and weigh between 1.5 to 2.5 tons.
# - **Coloration**: Sleek, dark gray to blackish body, with white underparts.
# - **Tusk**: A single, spiraling tusk (up to 3 meters long) that grows from a single upper tooth. The tusk is made of **enamel and dentin**, and is highly sensitive.
# - **Males and females**: Males typically have longer, more pronounced tusks, which may play a role in mating or social displays.
#
# #### 🐬 Social Behavior
# - Narwhals are **social animals**, often traveling in groups (sometimes up to 100 individuals).
# - They are known for their **seasonal migration patterns** — moving between deep, ice-covered waters in winter and open waters in summer.
# - They often travel in tight-knit herds, with calves and mothers traveling together.
#
# #### 🐟 Diet
# - Narwhals are **benthic predators**, feeding primarily on **deep-sea and Arctic fish** such as cod, herring, and squid.
# - They also consume **invertebrates** and some marine mammals (rarely).
#
# #### 🐢 Reproduction & Lifespan
# - **Gestation period**: About 11 months.
# - **Lifespan**: Up

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(
                model="qwen/qwen3-4b-2507",
                base_url="http://localhost:1234/v1",
                api_key="nothing",
                temperature=0.7,
                max_tokens=512),
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 27
#      24 graph = builder.compile()
#      26 # View
# ---> 27 display(Image(graph.get_graph().draw_mermaid_png()))
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph.py:694, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url)
#     684 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     685     draw_mermaid_png,
#     686 )
#     688 mermaid_syntax = self.draw_mermaid(
#     689     curve_style=curve_style,
#     690     node_colors=node_colors,
#     691     wrap_label_n_words=wrap_label_n_words,
#     692     frontmatter_config=frontmatter_config,
#     693 )
# --> 694 return draw_mermaid_png(
#     695     mermaid_syntax=mermaid_syntax,
#     696     output_file_path=output_file_path,
#     697     draw_method=draw_method,
#     698     background_color=background_color,
#     699     padding=padding,
#     700     max_retries=max_retries,
#     701     retry_delay=retry_delay,
#     702     base_url=base_url,
#     703 )
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:310, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url)
#     304     img_bytes = asyncio.run(
#     305         _render_mermaid_using_pyppeteer(
#     306             mermaid_syntax, output_file_path, background_color, padding
#     307         )
#     308     )
#     309 elif draw_method == MermaidDrawMethod.API:
# --> 310     img_bytes = _render_mermaid_using_api(
#     311         mermaid_syntax,
#     312         output_file_path=output_file_path,
#     313         background_color=background_color,
#     314         max_retries=max_retries,
#     315         retry_delay=retry_delay,
#     316         base_url=base_url,
#     317     )
#     318 else:
#     319     supported_methods = ", ".join([m.value for m in MermaidDrawMethod])
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/runnables/graph_mermaid.py:448, in _render_mermaid_using_api(mermaid_syntax, output_file_path, background_color, file_type, max_retries, retry_delay, base_url)
#     446 for attempt in range(max_retries + 1):
#     447     try:
# --> 448         response = requests.get(image_url, timeout=10)
#     449         if response.status_code == requests.codes.ok:
#     450             img_bytes = response.content
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     751 try:
#     752     sock: socket.socket | ssl.SSLSocket
# --> 753     self.sock = sock = self._new_conn()
#     754     server_hostname: str = self.host
#     755     tls_in_tls = False
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(
                model="qwen/qwen3-4b-2507",
                base_url="http://localhost:1234/v1",
                api_key="nothing",
                temperature=0.7,
                max_tokens=512),
            allow_partial=False
        )
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Example of trimming messages
# ----> 2 trim_messages(
#       3             messages,
#       4             max_tokens=100,
#       5             strategy="last",
#       6             token_counter=ChatOpenAI(
#       7                 model="qwen/qwen3-4b-2507",
#       8                 base_url="http://localhost:1234/v1",
#       9                 api_key="nothing",
#      10                 temperature=0.7,
#      11                 max_tokens=512),
#      12             allow_partial=False
#      13         )
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/messages/utils.py:405, in _runnable_support.<locals>.wrapped(messages, **kwargs)
#     402 from langchain_core.runnables.base import RunnableLambda  # noqa: PLC0415
#     404 if messages is not None:
# --> 405     return func(messages, **kwargs)
#     406 return RunnableLambda(partial(func, **kwargs), name=func.__name__)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/messages/utils.py:1002, in trim_messages(messages, max_tokens, token_counter, strategy, allow_partial, end_on, start_on, include_system, text_splitter)
#     993     return _first_max_tokens(
#     994         messages,
#     995         max_tokens=max_tokens,
#    (...)    999         end_on=end_on,
#    1000     )
#    1001 if strategy == "last":
# -> 1002     return _last_max_tokens(
#    1003         messages,
#    1004         max_tokens=max_tokens,
#    1005         token_counter=list_token_counter,
#    1006         allow_partial=allow_partial,
#    1007         include_system=include_system,
#    1008         start_on=start_on,
#    1009         end_on=end_on,
#    1010         text_splitter=text_splitter_fn,
#    1011     )
#    1012 msg = f"Unrecognized {strategy=}. Supported strategies are 'last' and 'first'."
#    1013 raise ValueError(msg)
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/messages/utils.py:1548, in _last_max_tokens(messages, max_tokens, token_counter, text_splitter, allow_partial, include_system, start_on, end_on)
#    1545     system_tokens = token_counter([system_message])
#    1546     remaining_tokens = max(0, max_tokens - system_tokens)
# -> 1548 reversed_result = _first_max_tokens(
#    1549     reversed_messages,
#    1550     max_tokens=remaining_tokens,
#    1551     token_counter=token_counter,
#    1552     text_splitter=text_splitter,
#    1553     partial_strategy="last" if allow_partial else None,
#    1554     end_on=start_on,
#    1555 )
#    1557 # Re-reverse the messages and add back the system message if needed
#    1558 result = reversed_result[::-1]
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_core/messages/utils.py:1408, in _first_max_tokens(messages, max_tokens, token_counter, text_splitter, partial_strategy, end_on)
#    1405     return messages
#    1407 # Check if all messages already fit within token limit
# -> 1408 if token_counter(messages) <= max_tokens:
#    1409     # When all messages fit, only apply end_on filtering if needed
#    1410     if end_on:
#    1411         for _ in range(len(messages)):
#
# File ~/workspace/langchain-academy/lc-academy-env/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1681, in BaseChatOpenAI.get_num_tokens_from_messages(self, messages, tools)
#    1674 else:
#    1675     msg = (
#    1676         f"get_num_tokens_from_messages() is not presently implemented "
#    1677         f"for model {model}. See "
#    1678         "https://platform.openai.com/docs/guides/text-generation/managing-tokens"
#    1679         " for information on how messages are converted to tokens."
#    1680     )
# -> 1681     raise NotImplementedError(msg)
#    1682 num_tokens = 0
#    1683 messages_dict = [_convert_message_to_dict(m) for m in messages]
#
# NotImplementedError: get_num_tokens_from_messages() is not presently implemented for model qwen/qwen3-4b-2507. See https://platform.openai.com/docs/guides/text-generation/managing-tokens for information on how messages are converted to tokens.

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
